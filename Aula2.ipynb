# %% [markdown]
# <a href="https://colab.research.google.com/github/GustavoLeripio/Gustavo.codefico/blob/main/Aula2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![modulo 5 header.png](data:image/png;base64,...)

# %% [markdown]
# Nesta lista de exercícios, você terá a oportunidade de criar uma página utilizando os elementos de listas (ordenadas e não ordenadas) e tabelas.
#
# Instruções:
#
# 1. Título: Comece criando um documento HTML válido com uma estrutura básica, incluindo a declaração <!DOCTYPE html>, as tags \<html>, \<head> e \<body>. Defina um título apropriado para a página.
#
# 2. Cabeçalho: No \<body>, crie um cabeçalho (\<h1>) que descreva o propósito da lista/tabela referente a questão. Por exemplo: ("Top 5 frutas favoritas").
#
# 3. Você pode criar um documento HTML para cada questão ou fazer no mesmo documento, apenas tenha atenção com a organização do código.
#
# Questão 1: \
#
# * Crie uma lista não ordenada (\<ul>) com pelo menos 5 itens que representam suas metas para o próximo ano.
#
# Questão 2: \
# * Faça uma lista ordenada (\<ol>), utilizando o atributo (type = " i "), com as suas cinco frutas
# favoritas. \
#
# Questão 3: \
# * Construa uma lista de descrição (\<dl>) que represente seus hoobies favoritos. Cada item da lista deve consistir em um termo (o hobbie) (\<dt>) seguido por uma breve descrição (\<dd>).
#
# Questão 4: \
#  * Crie uma lista não ordenada (\<ul>) que represente 3 estados (vocês poderão escolher) e aninhe listas não ordenadas (\<ol>) com pelos menos 3 cidades de cada estado. Nessa questão estamos utilizando o conceito de listas aninhadas, basicamente são listas que estão contidas dentro de outros itens de uma lista. Como foi visto na aula, podemos utilizar uma lista dentro de outra lista.
#
# Questão 5: \
# * Crie uma tabela que tenha produtos e o seus preços. Para isso crie uma linha cabeçalho (utilizando (\<tr>) e (\<th>) ) para ter a coluna de produtos e a coluna de preço, em seguida preencha a as células da tabela com os produtos e seus respectivos preços (utilizando (\<tr>) e (\<td>)), você pode escolher seus produtos e os seus valores. Não se preocupe com as bordas da tabela, iremos ver mais a frente com o CSS.
# * Exemplo: \
#   Temos os produtos com seus preços: Chinelo = 25,00 reais , Sapato = 200,00 reais e Bermuda =  75,00 reais.
#
#     ![image.png](data:image/png;base64,...)

# %% [markdown]
# file:///C:/Users/gusta/Downloads/gustavo.html

# %%
<!DOCTYPE html>
<html>
<head>
    <title>Exercício de Listas e Tabelas</title>
</head>
<body>
    <h1>Exercício de Listas e Tabelas</h1>

    <h2>Questão 1:</h2>
    <ul>
        <li>Meta 1: Aprender programação</li>
        <li>Meta 2: Viajar</li>
        <li>Meta 3: Comoçar na area da programacao</li>
        <li>Meta 4: Sair da minha bolha de sempre</li>
        <li>Meta 5: Me arriscar mais na vida</li>
    </ul>

    <h2>Questão 2:</h2>
    <ol type="i">
        <li>Morango</li>
        <li>Uva</li>
        <li>Maçã</li>
        <li>Caqui</li>
        <li>Melancia</li>
    </ol>

    <h2>Questão 3:</h2>
    <dl>
        <dt>Jogar</dt>
        <dd>Conseguir alcancar meus objetivos nos jogos que gosto</dd>

        <dt>Ficar com minha familia</dt>
        <dd>Gosto muito de estar perto de quem eu amo</dd>

        <dt>Viagens</dt>
        <dd>Gosto de conhecer lugares novos, e pessoas novas daquele lugar.</dd>

        <dt>Dormir KKK</dt>
        <dd>Gosto muito de dormir</dd>

        <dt>Cozinhar</dt>
        <dd>Gosto de cozinhar, principallmento se for um churrasco</dd>
    </dl>

    <h2>Questão 4:</h2>
    <ul>
        <li>São Paulo
            <ol>
                <li>Osasco</li>
                <li>Campinas</li>
                <li>São Bernardo do Campo</li>
            </ol>
        </li>
        <li>Rio de Janeiro
            <ol>
                <li>Barra da tijuca</li>
                <li>Niterói</li>
                <li>Campos dos Goytacazes</li>
            </ol>
        </li>
        <li>Minas Gerais
            <ol>
                <li>Belo Horizonte</li>
                <li>Uberlândia</li>
                <li>Ouro Preto</li>
            </ol>
        </li>
    </ul>

    <h2>Questão 5:</h2>
    <table>
        <tr>
            <th>Produto</th>
            <th>Preço</th>
        </tr>
        <tr>
            <td>Chinelo</td>
            <td>25,00 reais</td>
        </tr>
        <tr>
            <td>Sapato</td>
            <td>200,00 reais</td>
        </tr>
        <tr>
            <td>Bermuda</td>
            <td>75,00 reais</td>
        </tr>
    </table>
</body>
</html>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
